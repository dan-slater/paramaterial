# %% [markdown]
# # Vos Ringing Study

# %%
import shutil

import numpy as np
import pandas as pd
import importlib

from matplotlib import pyplot as plt

import paramaterial as pam
from paramaterial.plug import DataSet

# %% [markdown]
# ## Data Preparation

# %%
info = pam.preparing.make_info_table('data/00 backup data')
info
# Out:
#    test id old filename test type material temperature rate
# 0      NaN     UA01.csv       NaN      NaN         NaN  NaN
# 1      NaN     UA02.csv       NaN      NaN         NaN  NaN
# 2      NaN     UA03.csv       NaN      NaN         NaN  NaN
# 3      NaN     UA04.csv       NaN      NaN         NaN  NaN
# 4      NaN     UA05.csv       NaN      NaN         NaN  NaN
# 5      NaN     UA06.csv       NaN      NaN         NaN  NaN
# 6      NaN     UA07.csv       NaN      NaN         NaN  NaN
# 7      NaN     UA08.csv       NaN      NaN         NaN  NaN
# 8      NaN     UA09.csv       NaN      NaN         NaN  NaN
# 9      NaN     UA10.csv       NaN      NaN         NaN  NaN
# 10     NaN     UA11.csv       NaN      NaN         NaN  NaN
# 11     NaN     UA12.csv       NaN      NaN         NaN  NaN
# 12     NaN     UA13.csv       NaN      NaN         NaN  NaN
# 13     NaN     UA14.csv       NaN      NaN         NaN  NaN
# 14     NaN     UA15.csv       NaN      NaN         NaN  NaN
# 15     NaN     UA16.csv       NaN      NaN         NaN  NaN
# 16     NaN     UA17.csv       NaN      NaN         NaN  NaN
# 17     NaN     UA18.csv       NaN      NaN         NaN  NaN
# 18     NaN     UA19.csv       NaN      NaN         NaN  NaN
# 19     NaN     UA20.csv       NaN      NaN         NaN  NaN
# 20     NaN     UA21.csv       NaN      NaN         NaN  NaN
# 21     NaN     UA22.csv       NaN      NaN         NaN  NaN
# 22     NaN     UA23.csv       NaN      NaN         NaN  NaN
# 23     NaN     UA24.csv       NaN      NaN         NaN  NaN
# 24     NaN     UA25.csv       NaN      NaN         NaN  NaN
# 25     NaN     UA26.csv       NaN      NaN         NaN  NaN
# 26     NaN     UA27.csv       NaN      NaN         NaN  NaN
# 27     NaN     UA28.csv       NaN      NaN         NaN  NaN
# 28     NaN     UA29.csv       NaN      NaN         NaN  NaN
# 29     NaN     UA30.csv       NaN      NaN         NaN  NaN
# 30     NaN     UA31.csv       NaN      NaN         NaN  NaN
# 31     NaN     UA32.csv       NaN      NaN         NaN  NaN

# %%
info['test id'] = [name[:-4] for name in info['old filename']]
info['test type'] = ['UA']*len(info)
info['material'] = ['AA1015']*len(info)
info['temperature'] = [25]*len(info)
info.to_excel('info/00 backup info incomplete.xlsx')
info
# Out:
#    test id old filename test type material  temperature rate
# 0     UA01     UA01.csv        UA   AA1015           25  NaN
# 1     UA02     UA02.csv        UA   AA1015           25  NaN
# 2     UA03     UA03.csv        UA   AA1015           25  NaN
# 3     UA04     UA04.csv        UA   AA1015           25  NaN
# 4     UA05     UA05.csv        UA   AA1015           25  NaN
# 5     UA06     UA06.csv        UA   AA1015           25  NaN
# 6     UA07     UA07.csv        UA   AA1015           25  NaN
# 7     UA08     UA08.csv        UA   AA1015           25  NaN
# 8     UA09     UA09.csv        UA   AA1015           25  NaN
# 9     UA10     UA10.csv        UA   AA1015           25  NaN
# 10    UA11     UA11.csv        UA   AA1015           25  NaN
# 11    UA12     UA12.csv        UA   AA1015           25  NaN
# 12    UA13     UA13.csv        UA   AA1015           25  NaN
# 13    UA14     UA14.csv        UA   AA1015           25  NaN
# 14    UA15     UA15.csv        UA   AA1015           25  NaN
# 15    UA16     UA16.csv        UA   AA1015           25  NaN
# 16    UA17     UA17.csv        UA   AA1015           25  NaN
# 17    UA18     UA18.csv        UA   AA1015           25  NaN
# 18    UA19     UA19.csv        UA   AA1015           25  NaN
# 19    UA20     UA20.csv        UA   AA1015           25  NaN
# 20    UA21     UA21.csv        UA   AA1015           25  NaN
# 21    UA22     UA22.csv        UA   AA1015           25  NaN
# 22    UA23     UA23.csv        UA   AA1015           25  NaN
# 23    UA24     UA24.csv        UA   AA1015           25  NaN
# 24    UA25     UA25.csv        UA   AA1015           25  NaN
# 25    UA26     UA26.csv        UA   AA1015           25  NaN
# 26    UA27     UA27.csv        UA   AA1015           25  NaN
# 27    UA28     UA28.csv        UA   AA1015           25  NaN
# 28    UA29     UA29.csv        UA   AA1015           25  NaN
# 29    UA30     UA30.csv        UA   AA1015           25  NaN
# 30    UA31     UA31.csv        UA   AA1015           25  NaN
# 31    UA32     UA32.csv        UA   AA1015           25  NaN

# %% [markdown]
# Manually add in remaining metadata.

# %%
pd.read_excel('info/00 backup info.xlsx')
# Out:
#    test id old filename test type material  temperature  rate    L_f  \
# 0     UA01     UA01.csv        UA   AA1015           25     1  4.206
# 1     UA02     UA02.csv        UA   AA1015           25     1  4.234
# 2     UA03     UA03.csv        UA   AA1015           25     1  4.253
# 3     UA04     UA04.csv        UA   AA1015           25    10  3.889
# 4     UA05     UA05.csv        UA   AA1015           25    10  3.864
# 5     UA06     UA06.csv        UA   AA1015           25    10  3.894
# 6     UA07     UA07.csv        UA   AA1015           25    30  3.878
# 7     UA08     UA08.csv        UA   AA1015           25    30  3.853
# 8     UA09     UA09.csv        UA   AA1015           25    30  3.855
# 9     UA10     UA10.csv        UA   AA1015           25    20  3.867
# 10    UA11     UA11.csv        UA   AA1015           25    20  3.882
# 11    UA12     UA12.csv        UA   AA1015           25    20  3.876
# 12    UA13     UA13.csv        UA   AA1015           25    50  3.854
# 13    UA14     UA14.csv        UA   AA1015           25    50  3.872
# 14    UA15     UA15.csv        UA   AA1015           25    50  3.869
# 15    UA16     UA16.csv        UA   AA1015           25    50  3.865
# 16    UA17     UA17.csv        UA   AA1015           25    70  3.887
# 17    UA18     UA18.csv        UA   AA1015           25    70  3.878
# 18    UA19     UA19.csv        UA   AA1015           25    70  3.646
# 19    UA20     UA20.csv        UA   AA1015           25    30  3.999
# 20    UA21     UA21.csv        UA   AA1015           25    30  3.787
# 21    UA22     UA22.csv        UA   AA1015           25    30  3.782
# 22    UA23     UA23.csv        UA   AA1015           25    50  3.763
# 23    UA24     UA24.csv        UA   AA1015           25    50  3.788
# 24    UA25     UA25.csv        UA   AA1015           25    50  3.776
# 25    UA26     UA26.csv        UA   AA1015           25    70  3.779
# 26    UA27     UA27.csv        UA   AA1015           25    70  3.766
# 27    UA28     UA28.csv        UA   AA1015           25    70  3.778
# 28    UA29     UA29.csv        UA   AA1015           25   110  3.796
# 29    UA30     UA30.csv        UA   AA1015           25   110  3.748
# 30    UA31     UA31.csv        UA   AA1015           25   110  3.758
# 31    UA32     UA32.csv        UA   AA1015           25   150  3.772
#
#          D_0     L_0
# 0   7.037333  10.588
# 1   7.030333  10.592
# 2   7.048667  10.600
# 3   7.014000  10.609
# 4   7.026333  10.584
# 5   7.024000  10.612
# 6   7.026333  10.614
# 7   7.026000  10.586
# 8   7.017000  10.588
# 9   7.062000  10.602
# 10  7.032000  10.613
# 11  7.022667  10.597
# 12  7.033000  10.601
# 13  7.066000  10.602
# 14  7.047000  10.597
# 15  7.024333  10.593
# 16  7.031667  10.606
# 17  7.028333  10.608
# 18  7.040000  10.580
# 19  7.058000  10.586
# 20  7.030667  10.604
# 21  7.064000  10.589
# 22  7.055000  10.586
# 23  7.020000  10.621
# 24  7.072000  10.594
# 25  7.069000  10.596
# 26  7.045667  10.583
# 27  7.061000  10.600
# 28  7.030667  10.612
# 29  7.038333  10.582
# 30  7.037667  10.580
# 31  7.035000  10.613

# %%
pam.preparing.check_column_headers('data/00 backup data')
# Out:
# Checking column headers...
# First file headers:
# 	['Time (sec)', 'AirRamPres (kN)', 'Force (kN)', 'Jaw (mm)', 'PowAngle (deg)', 'PTemp', 'Strain', 'Stress (MPa)', 'Stroke (mm)', 'wedge (mm)', 'Pram', 'ramError', 'Pwedge']
# Headers in all files are the same as in the first file.

# %% [markdown]
# Copy files from backup then leave backup.

# %%
pam.preparing.copy_folder_and_files('data/00 backup data', 'data/01 prepared data')
shutil.copy('info/00 backup info.xlsx', 'info/01 prepared info.xlsx')
# Out:
# Copied 32 files from data/00 backup data to data/01 prepared data.
# 'info/01 prepared info.xlsx'

# %% [markdown]
# # Data Processing
#
# Now that we have prepared the data, we can use the DataSet class for processing.

# %%
dataset = pam.plug.DataSet('data/01 prepared data', 'info/01 prepared info.xlsx')
fig, ax = plt.subplots(1,1,figsize=(9,6))
dataset.plot(ax, x='Strain', y='Stress (MPa)', ylabel='Stress (MPa)', legend=False, colourby='rate')

# %% [markdown]
# Multiply the srtess and strain columns in all the datafiles by -1.

# %%
def neg_stress(dataitem):
    dataitem.data['Stress (MPa)'] = -dataitem.data['Stress (MPa)']
    dataitem.data['Strain'] = -dataitem.data['Strain']
    return dataitem
dataset.add_proc_op(neg_stress)
dataset.output('data/02 processed data',
               'info/02 processed info.xlsx')
dataset = DataSet('data/02 processed data',
                  'info/02 processed info.xlsx')
fig, ax = plt.subplots(1,1,figsize=(9,6))
dataset.plot(ax, x='Strain', y='Stress (MPa)', ylabel='Stress (MPa)', legend=False, colourby='rate')
plt.show()
# Out:
# 100%|██████████| 32/32 [00:04<00:00,  6.45it/s]

# %%
dataset = DataSet('data/02 processed data',
                  'info/02 processed info.xlsx')
fig, ax = plt.subplots(1,1,figsize=(9,6))
dataset.plot(ax, x='Time (sec)', y='Stress (MPa)', ylabel='Stress (MPa)', legend=False, colourby='rate')
ax.set_xlim(xmin=0.04, xmax=0.2)
# Out:
# (0.04, 0.2)

# %%
dataset = DataSet('data/02 processed data',
                  'info/02 processed info.xlsx')
fig, ax = plt.subplots(1,1,figsize=(9,6))
dataset.plot(ax, x='Time (sec)', y='Strain', ylabel='Strain', legend=False, colourby='rate', alpha=0.8)
ax.set_xlim(xmin=0.04, xmax=0.2)
# Out:
# (0.04, 0.2)
