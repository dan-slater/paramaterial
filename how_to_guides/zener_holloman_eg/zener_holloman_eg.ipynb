# %% [markdown]
# ## Example of Zener-Holloman Analysis

# %%
import paramaterial as pam

# %%
ds = pam.DataSet('data/zh_eg_data', 'info/zh_eg_info.xlsx')
ds
# Out:
# DataSet with 18 DataItems containing
# 	info: columns -> test_id, rate, temperature
# 	data: len = 200, columns -> Strain, Stress_MPa

# %%
ds = ds.apply(pam.find_flow_stress, flow_strain=0.2)
df = ds.info_table
df['temperature_K'] = df['temperature'] + 273.15
df['rate_s-1'] = df['rate']
df['Q_activation'] = 156000
ds.info_table = df
ds.info_table
# Out:
#        test_id rate temperature flow_strain flow_stress_MPa temperature_K  \
# 0   test_id_01  100         300         0.2      204.376118        573.15
# 1   test_id_02  100         330         0.2      193.656675        603.15
# 2   test_id_03  100         360         0.2      192.466052        633.15
# 3   test_id_04  100         400         0.2       195.11362        673.15
# 4   test_id_05   10         300         0.2      129.654368        573.15
# 5   test_id_06   10         330         0.2      118.381516        603.15
# 6   test_id_07   10         360         0.2      104.920622        633.15
# 7   test_id_08   10         400         0.2       90.248088        673.15
# 8   test_id_09   10         450         0.2       75.716773        723.15
# 9   test_id_10   10         500         0.2       61.234414        773.15
# 10  test_id_11    1         360         0.2       93.123854        633.15
# 11  test_id_12    1         400         0.2       75.785328        673.15
# ...

# %%
pam.plot_ZH_regression(ds)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='lnZ', ylabel='Flow stress (MPa)'>

# %%
pam.plot_ZH_regression(ds, group_by='rate_s-1', color_by='temperature', marker_by='rate_s-1', calculate=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='lnZ', ylabel='Flow stress (MPa)'>

# %%
pam.plot_ZH_regression(ds, group_by='rate_s-1', color_by='rate_s-1', marker_by='rate_s-1', calculate=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='lnZ', ylabel='Flow stress (MPa)'>

# %%
pam.plot_ZH_regression(ds, group_by='rate_s-1', color_by='rate_s-1', marker_by='rate_s-1', calculate=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='lnZ', ylabel='Flow stress (MPa)'>

# %%
ds = ds.apply(pam.calculate_ZH_parameter)
ds.info_table
# Out:
#        test_id rate temperature flow_strain flow_stress_MPa temperature_K  \
# 0   test_id_01  100         300         0.2      204.376118        573.15
# 1   test_id_02  100         330         0.2      193.656675        603.15
# 2   test_id_03  100         360         0.2      192.466052        633.15
# 3   test_id_04  100         400         0.2       195.11362        673.15
# 4   test_id_05   10         300         0.2      129.654368        573.15
# 5   test_id_06   10         330         0.2      118.381516        603.15
# 6   test_id_07   10         360         0.2      104.920622        633.15
# 7   test_id_08   10         400         0.2       90.248088        673.15
# 8   test_id_09   10         450         0.2       75.716773        723.15
# 9   test_id_10   10         500         0.2       61.234414        773.15
# 10  test_id_11    1         360         0.2       93.123854        633.15
# 11  test_id_12    1         400         0.2       75.785328        673.15
# ...

# %%
ds = pam.apply_ZH_regression(ds)
ds.info_table
# Out:
#        test_id rate temperature flow_strain flow_stress_MPa temperature_K  \
# 0   test_id_01  100         300         0.2      204.376118        573.15
# 1   test_id_02  100         330         0.2      193.656675        603.15
# 2   test_id_03  100         360         0.2      192.466052        633.15
# 3   test_id_04  100         400         0.2       195.11362        673.15
# 4   test_id_05   10         300         0.2      129.654368        573.15
# 5   test_id_06   10         330         0.2      118.381516        603.15
# 6   test_id_07   10         360         0.2      104.920622        633.15
# 7   test_id_08   10         400         0.2       90.248088        673.15
# 8   test_id_09   10         450         0.2       75.716773        723.15
# 9   test_id_10   10         500         0.2       61.234414        773.15
# 10  test_id_11    1         360         0.2       93.123854        633.15
# 11  test_id_12    1         400         0.2       75.785328        673.15
# ...

# %%
pam.plot_ZH_regression(ds)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <AxesSubplot:xlabel='lnZ', ylabel='Flow stress (MPa)'>

# %%
import numpy as np
Z = 82*np.exp(156000/(8.3145*(440+273.15)))
np.log(Z)
# Out:
# 30.715915111878598

# %%
np.log(np.exp(30.45))
# Out:
# 30.45
